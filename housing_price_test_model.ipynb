# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import PolynomialFeatures

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, r2_score

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.impute import SimpleImputer  # <-- IMPORT THE IMPUTER

# %% [markdown]
# Storing the data in a dataframe

# %%
df = pd.read_parquet("DKHousingPrices.parquet", engine='fastparquet')

# %%
print(df["date"].min(), "to", df["date"].max())
df.head()
# Out:
# 1992-01-05 00:00:00 to 2024-10-26 00:00:00
#         date  quarter  house_id   house_type    sales_type  year_build  \
# 0 2024-10-26      219         0        Villa  regular_sale        1974
# 1 2024-10-26      219         2  Summerhouse  regular_sale        1956
# 2 2024-10-26      219         1         Farm  regular_sale        1955
# 3 2024-10-25      219         3    Apartment   family_sale        1945
# 4 2024-10-25      219         4        Villa  regular_sale        1967
#
#    purchase_price  %_change_between_offer_and_purchase  no_rooms    sqm  \
# 0         4350000                                  0.0         5  215.0
# 1          450000                                  0.0         3   36.0
# 2         6600000                                  0.0         3  180.0
# 3         1495000                                  0.0         2   64.0
# 4         3375000                                  0.0         5  176.0
#
#       sqm_price                     address  zip_code        city  \
# 0  20232.558594               Kildevangen 5      8382    Hinnerup
# 1  12500.000000                Lykkestien 2      4400  Kalundborg
# 2  36666.667969               Sæderupvej 58      9260     Gistrup
# 3  23359.375000  Tage-Hansens Gade 5, 1. tv      8000    Aarhus C
# 4  19176.136719          Chr.Winthers Vej 5      8600   Silkeborg
#
#                  area   region  nom_interest_rate%  dk_ann_infl_rate%  \
# 0  East & mid jutland  Jutland                 3.1                NaN
# 1       Other islands  Zealand                 3.1                NaN
# 2       North jutland  Jutland                 3.1                NaN
# 3  East & mid jutland  Jutland                 3.1                NaN
# 4  East & mid jutland  Jutland                 3.1                NaN
#
#    yield_on_mortgage_credit_bonds%
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN

# %%
#Drop all rows with na in the sqm column
df = df.dropna(subset=["city", "quarter","house_type", "sales_type", "year_build", "no_rooms", "sqm", "area", "dk_ann_infl_rate%", "nom_interest_rate%", "yield_on_mortgage_credit_bonds%"])
df.head()
# Out:
#            date  quarter  house_id   house_type    sales_type  year_build  \
# 1193 2024-09-30      218      1300    Apartment  regular_sale        1971
# 1194 2024-09-30      218      1307  Summerhouse  regular_sale        2009
# 1195 2024-09-30      218      1301    Apartment  regular_sale        1940
# 1196 2024-09-30      218      1302  Summerhouse   family_sale        1950
# 1197 2024-09-30      218      1303    Apartment  regular_sale        1974
#
#       purchase_price  %_change_between_offer_and_purchase  no_rooms   sqm  \
# 1193         1765000                                  0.0         3  78.0
# 1194          590939                                  0.0         3  50.0
# 1195         1750000                                  0.0         2  56.0
# 1196         1080000                                  0.0         4  72.0
# 1197         2300000                                  0.0         1  50.0
#
#          sqm_price                  address  zip_code            city  \
# 1193  22628.205078      Hedekæret 38, 1. th      2640      Hedehusene
# 1194  11818.780273             Violstien 11      2635           Ishøj
# 1195  31250.000000  Buddingevej 72I, st. tv      2800  Kongens Lyngby
# 1196  15000.000000          Frederiksvej 35      3730            Nexø
# 1197  46000.000000     Thyrasgade 4, 4. 508      2200     København N
#
#                      area    region  nom_interest_rate%  dk_ann_infl_rate%  \
# 1193  Capital, Copenhagen   Zealand                3.35               1.13
# 1194  Capital, Copenhagen   Zealand                3.35               1.13
# 1195  Capital, Copenhagen   Zealand                3.35               1.13
# 1196             Bornholm  Bornholm                3.35               1.13
# 1197  Capital, Copenhagen   Zealand                3.35               1.13
#
#       yield_on_mortgage_credit_bonds%
# 1193                             4.34
# 1194                             4.34
# 1195                             4.34
# 1196                             4.34
# 1197                             4.34

# %% [markdown]
# #### Quarter skal laves til en float istedet for datetime

# %%
#Convert a Period column to the number of days/months/years since a reference date
df["quarter"] = df["quarter"].astype("int64")
df.head()
# Out:
#            date  quarter  house_id   house_type    sales_type  year_build  \
# 1193 2024-09-30      218      1300    Apartment  regular_sale        1971
# 1194 2024-09-30      218      1307  Summerhouse  regular_sale        2009
# 1195 2024-09-30      218      1301    Apartment  regular_sale        1940
# 1196 2024-09-30      218      1302  Summerhouse   family_sale        1950
# 1197 2024-09-30      218      1303    Apartment  regular_sale        1974
#
#       purchase_price  %_change_between_offer_and_purchase  no_rooms   sqm  \
# 1193         1765000                                  0.0         3  78.0
# 1194          590939                                  0.0         3  50.0
# 1195         1750000                                  0.0         2  56.0
# 1196         1080000                                  0.0         4  72.0
# 1197         2300000                                  0.0         1  50.0
#
#          sqm_price                  address  zip_code            city  \
# 1193  22628.205078      Hedekæret 38, 1. th      2640      Hedehusene
# 1194  11818.780273             Violstien 11      2635           Ishøj
# 1195  31250.000000  Buddingevej 72I, st. tv      2800  Kongens Lyngby
# 1196  15000.000000          Frederiksvej 35      3730            Nexø
# 1197  46000.000000     Thyrasgade 4, 4. 508      2200     København N
#
#                      area    region  nom_interest_rate%  dk_ann_infl_rate%  \
# 1193  Capital, Copenhagen   Zealand                3.35               1.13
# 1194  Capital, Copenhagen   Zealand                3.35               1.13
# 1195  Capital, Copenhagen   Zealand                3.35               1.13
# 1196             Bornholm  Bornholm                3.35               1.13
# 1197  Capital, Copenhagen   Zealand                3.35               1.13
#
#       yield_on_mortgage_credit_bonds%
# 1193                             4.34
# 1194                             4.34
# 1195                             4.34
# 1196                             4.34
# 1197                             4.34

# %% [markdown]
# ### Make dummy variables

# %%
X = pd.get_dummies(df[["quarter","house_type", "sales_type", "year_build", "no_rooms", "sqm", "zip_code", "nom_interest_rate%" ]])
y = df["purchase_price"]
X.shape, y.shape
X.head()
# Out:
#          quarter  year_build  no_rooms    sqm  nom_interest_rate%  \
# 673243       186        2007         3  105.0                 0.0
# 162689       210        1945         3   88.0                 0.0
# 1020609      152        1961         5  161.0                 4.0
# 363784       203        1965         6  151.0                 0.0
# 515909       197        1969         1   50.0                 0.0
#
#          house_type_Apartment  house_type_Farm  house_type_Summerhouse  \
# 673243                   True            False                   False
# 162689                  False            False                   False
# 1020609                 False            False                   False
# 363784                  False            False                   False
# 515909                   True            False                   False
#
#          house_type_Townhouse  house_type_Villa  ...  zip_code_9830  \
# 673243                  False             False  ...          False
# 162689                  False              True  ...          False
# 1020609                 False              True  ...          False
# 363784                  False              True  ...          False
# 515909                  False             False  ...          False
#
#          zip_code_9850  zip_code_9870  zip_code_9881  zip_code_9900  \
# 673243           False          False          False          False
# 162689           False          False          False          False
# 1020609          False          False          False          False
# 363784           False          False          False          False
# 515909           False          False          False          False
#
#          zip_code_9940  zip_code_9970  zip_code_9981  zip_code_9982  \
# 673243           False          False          False          False
# 162689           False          False          False          False
# 1020609          False          False          False          False
# 363784           False          False          False          False
# 515909           False          False          False          False
#
#          zip_code_9990
# 673243           False
# 162689           False
# 1020609          False
# 363784           False
# 515909           False
#
# [5 rows x 909 columns]

# %% [markdown]
# Make the training and testing split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create and fit the model
simple_model = LinearRegression()
simple_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Evaluate the model
print("Score on training set: {:.3f}".format(simple_model.score(X_train, y_train)))
print("Score on test set: {:.3f}".format(simple_model.score(X_test, y_test)))
# Out:
# Score on training set: 0.337
# Score on test set: 0.336

# %% [markdown]
# ## Polynomial Regression
# Now we will try to improve the model by making it polynomial.

# %%
# take a random 50% sample (deterministic via random_state) to reduce memory use
df = df.sample(frac=0.4, random_state=42).copy()
X = pd.get_dummies(df[["quarter","house_type", "sales_type", "year_build", "no_rooms", "sqm", "area", "nom_interest_rate%" ]])
y = df["purchase_price"]
X.head()
# Out:
#          quarter  year_build  no_rooms    sqm  nom_interest_rate%  \
# 88334        214        1971         5  166.0                 3.1
# 1202890      135        1965         4   83.0                 2.0
#
#          house_type_Apartment  house_type_Farm  house_type_Summerhouse  \
# 88334                   False            False                   False
# 1202890                 False            False                    True
#
#          house_type_Townhouse  house_type_Villa  ...  sales_type_other_sale  \
# 88334                   False              True  ...                  False
# 1202890                 False             False  ...                  False
#
#          sales_type_regular_sale  area_Bornholm  area_Capital, Copenhagen  \
# 88334                       True          False                     False
# 1202890                     True          False                     False
#
#          area_East & mid jutland  area_Fyn & islands  area_North Zealand  \
# 88334                      False               False               False
# 1202890                    False               False               False
#
#          area_North jutland  area_Other islands  area_South jutland
# 88334                 False                True               False
# 1202890               False                True               False
#
# [2 rows x 23 columns]

# %%
# make train-test split to get X_train, X_test, y_train, and y_test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# We use the code below to create polynomial features on the training data to the degree of 5.

# %%
# Let's try with degree 2 instead of 3 to reduce memory usage
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)  # Only transform, don't fit again

# %%
# Create and fit the model
poly_lr = LinearRegression()
poly_lr.fit(X_train_poly,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Evaluating the model

# %%
print("Score on training set: {:.3f}".format(poly_lr.score(X_train_poly, y_train)))
print("Score on test set: {:.3f}".format(poly_lr.score(X_test_poly, y_test)))
# Out:
# Score on training set: nan
# Score on test set: nan
# c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\sklearn\metrics\_regression.py:1283: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\sklearn\metrics\_regression.py:1283: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %% [markdown]
# ## K-nearest neighbor

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler

df = pd.read_parquet("DKHousingPrices.parquet", engine='fastparquet')

# %%
# take a random 50% sample (deterministic via random_state) to reduce memory use
df = df.sample(frac=0.4, random_state=42).copy()
X = pd.get_dummies(df[["quarter","house_type", "sales_type", "year_build", "no_rooms", "sqm", "zip_code", "nom_interest_rate%" ]])
y = df["purchase_price"]
X.head()
# Out:
#          quarter  year_build  no_rooms    sqm  zip_code  nom_interest_rate%  \
# 181839       209        2004         5   98.0      6300                0.00
# 1358524      115        1999         3  108.0      3600                4.25
# 1068900      148        1993         3   63.0      6792                3.50
# 413648       201        1900         5  232.0      6880                0.00
# 1237802      131        1939         2   39.0      8000                3.25
#
#          house_type_Apartment  house_type_Farm  house_type_Summerhouse  \
# 181839                  False            False                   False
# 1358524                  True            False                   False
# 1068900                 False            False                    True
# 413648                  False            False                   False
# 1237802                  True            False                   False
#
#          house_type_Townhouse  house_type_Villa  sales_type_-  \
# 181839                  False              True         False
# 1358524                 False             False         False
# 1068900                 False             False         False
# 413648                  False              True         False
# 1237802                 False             False         False
#
#          sales_type_auction  sales_type_family_sale  sales_type_other_sale  \
# 181839                False                    True                  False
# 1358524               False                   False                  False
# 1068900               False                   False                  False
# 413648                False                   False                  False
# 1237802               False                   False                  False
#
#          sales_type_regular_sale
# 181839                     False
# 1358524                     True
# 1068900                     True
# 413648                      True
# 1237802                     True

# %%
print(df["date"].min(), "to", df["date"].max())
df.head()
# Out:
# 1992-01-05 00:00:00 to 2024-10-26 00:00:00
#               date  quarter  house_id   house_type    sales_type  year_build  \
# 181839  2022-06-20      209    170811        Villa   family_sale        2004
# 1358524 1998-10-14      115   1354316    Apartment  regular_sale        1999
# 1068900 2007-01-30      148   1062263  Summerhouse  regular_sale        1993
# 413648  2020-06-01      201    404565        Villa  regular_sale        1900
# 1237802 2002-12-07      131   1233523    Apartment  regular_sale        1939
#
#          purchase_price  %_change_between_offer_and_purchase  no_rooms    sqm  \
# 181839           816000                                  0.0         5   98.0
# 1358524         1777000                                  0.0         3  108.0
# 1068900         1550000                                  0.0         3   63.0
# 413648          1465000                                 -1.0         5  232.0
# 1237802          717780                                  0.0         2   39.0
#
#             sqm_price                       address  zip_code           city  \
# 181839    8326.530273  Marina Fiskenæs Feriepark 18      6300        Gråsten
# 1358524  16453.703125                  Nordkajen 16      3600  Frederikssund
# 1068900  24603.173828                 Ringvejen 157      6792           Rømø
# 413648    6314.655273                   Hustedvej 1      6880           Tarm
# 1237802  18404.615234        Ringkøbingvej 6, 1. tv      8000       Aarhus C
#
#                        area   region  nom_interest_rate%  dk_ann_infl_rate%  \
# 181839        South jutland  Jutland                0.00               7.70
# 1358524       North Zealand  Zealand                4.25               1.85
# 1068900       South jutland  Jutland                3.50               1.69
# 413648        South jutland  Jutland                0.00               0.42
# 1237802  East & mid jutland  Jutland                3.25               2.42
#
#          yield_on_mortgage_credit_bonds%
# 181839                              3.73
# 1358524                             6.27
# 1068900                             5.70
# 413648                              1.10
# 1237802                             6.69

# %%
#Drop all rows with na in the sqm column
df = df.dropna(subset=["city", "quarter","house_type", "sales_type", "year_build", "no_rooms", "sqm", "area", "dk_ann_infl_rate%", "nom_interest_rate%", "yield_on_mortgage_credit_bonds%", "zip_code"])
df.head()
# Out:
#               date  quarter  house_id   house_type    sales_type  year_build  \
# 181839  2022-06-20      209    170811        Villa   family_sale        2004
# 1358524 1998-10-14      115   1354316    Apartment  regular_sale        1999
# 1068900 2007-01-30      148   1062263  Summerhouse  regular_sale        1993
# 413648  2020-06-01      201    404565        Villa  regular_sale        1900
# 1237802 2002-12-07      131   1233523    Apartment  regular_sale        1939
#
#          purchase_price  %_change_between_offer_and_purchase  no_rooms    sqm  \
# 181839           816000                                  0.0         5   98.0
# 1358524         1777000                                  0.0         3  108.0
# 1068900         1550000                                  0.0         3   63.0
# 413648          1465000                                 -1.0         5  232.0
# 1237802          717780                                  0.0         2   39.0
#
#             sqm_price                       address  zip_code           city  \
# 181839    8326.530273  Marina Fiskenæs Feriepark 18      6300        Gråsten
# 1358524  16453.703125                  Nordkajen 16      3600  Frederikssund
# 1068900  24603.173828                 Ringvejen 157      6792           Rømø
# 413648    6314.655273                   Hustedvej 1      6880           Tarm
# 1237802  18404.615234        Ringkøbingvej 6, 1. tv      8000       Aarhus C
#
#                        area   region  nom_interest_rate%  dk_ann_infl_rate%  \
# 181839        South jutland  Jutland                0.00               7.70
# 1358524       North Zealand  Zealand                4.25               1.85
# 1068900       South jutland  Jutland                3.50               1.69
# 413648        South jutland  Jutland                0.00               0.42
# 1237802  East & mid jutland  Jutland                3.25               2.42
#
#          yield_on_mortgage_credit_bonds%
# 181839                              3.73
# 1358524                             6.27
# 1068900                             5.70
# 413648                              1.10
# 1237802                             6.69

# %%
df['zip_code'] = df['zip_code'].astype('object')

# %%
#Convert a Period column to the number of days/months/years since a reference date
df["quarter"] = df["quarter"].astype("int64")
df.head()
# Out:
#               date  quarter  house_id   house_type    sales_type  year_build  \
# 181839  2022-06-20      209    170811        Villa   family_sale        2004
# 1358524 1998-10-14      115   1354316    Apartment  regular_sale        1999
# 1068900 2007-01-30      148   1062263  Summerhouse  regular_sale        1993
# 413648  2020-06-01      201    404565        Villa  regular_sale        1900
# 1237802 2002-12-07      131   1233523    Apartment  regular_sale        1939
#
#          purchase_price  %_change_between_offer_and_purchase  no_rooms    sqm  \
# 181839           816000                                  0.0         5   98.0
# 1358524         1777000                                  0.0         3  108.0
# 1068900         1550000                                  0.0         3   63.0
# 413648          1465000                                 -1.0         5  232.0
# 1237802          717780                                  0.0         2   39.0
#
#             sqm_price                       address zip_code           city  \
# 181839    8326.530273  Marina Fiskenæs Feriepark 18     6300        Gråsten
# 1358524  16453.703125                  Nordkajen 16     3600  Frederikssund
# 1068900  24603.173828                 Ringvejen 157     6792           Rømø
# 413648    6314.655273                   Hustedvej 1     6880           Tarm
# 1237802  18404.615234        Ringkøbingvej 6, 1. tv     8000       Aarhus C
#
#                        area   region  nom_interest_rate%  dk_ann_infl_rate%  \
# 181839        South jutland  Jutland                0.00               7.70
# 1358524       North Zealand  Zealand                4.25               1.85
# 1068900       South jutland  Jutland                3.50               1.69
# 413648        South jutland  Jutland                0.00               0.42
# 1237802  East & mid jutland  Jutland                3.25               2.42
#
#          yield_on_mortgage_credit_bonds%
# 181839                              3.73
# 1358524                             6.27
# 1068900                             5.70
# 413648                              1.10
# 1237802                             6.69

# %%
# take a random 50% sample (deterministic via random_state) to reduce memory use
df = df.sample(frac=0.3, random_state=42).copy()
X = pd.get_dummies(df[["quarter","house_type", "sales_type", "year_build", "no_rooms", "sqm", "zip_code", "nom_interest_rate%" ]])
y = df["purchase_price"]
X.shape, y.shape
X.head()
# Out:
#          quarter  year_build  no_rooms    sqm  nom_interest_rate%  \
# 673243       186        2007         3  105.0                 0.0
# 162689       210        1945         3   88.0                 0.0
# 1020609      152        1961         5  161.0                 4.0
# 363784       203        1965         6  151.0                 0.0
# 515909       197        1969         1   50.0                 0.0
#
#          house_type_Apartment  house_type_Farm  house_type_Summerhouse  \
# 673243                   True            False                   False
# 162689                  False            False                   False
# 1020609                 False            False                   False
# 363784                  False            False                   False
# 515909                   True            False                   False
#
#          house_type_Townhouse  house_type_Villa  ...  zip_code_9830  \
# 673243                  False             False  ...          False
# 162689                  False              True  ...          False
# 1020609                 False              True  ...          False
# 363784                  False              True  ...          False
# 515909                  False             False  ...          False
#
#          zip_code_9850  zip_code_9870  zip_code_9881  zip_code_9900  \
# 673243           False          False          False          False
# 162689           False          False          False          False
# 1020609          False          False          False          False
# 363784           False          False          False          False
# 515909           False          False          False          False
#
#          zip_code_9940  zip_code_9970  zip_code_9981  zip_code_9982  \
# 673243           False          False          False          False
# 162689           False          False          False          False
# 1020609          False          False          False          False
# 363784           False          False          False          False
# 515909           False          False          False          False
#
#          zip_code_9990
# 673243           False
# 162689           False
# 1020609          False
# 363784           False
# 515909           False
#
# [5 rows x 909 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
df.dtypes
# Out:
# date                                   datetime64[ns]
# quarter                                         int64
# house_id                                        int64
# house_type                                   category
# sales_type                                   category
# year_build                                      int16
# purchase_price                                  int32
# %_change_between_offer_and_purchase           float32
# no_rooms                                         int8
# sqm                                           float32
# sqm_price                                     float32
# address                                        object
# zip_code                                       object
# city                                           object
# area                                         category
# region                                       category
# nom_interest_rate%                            float32
# dk_ann_infl_rate%                             float32
# yield_on_mortgage_credit_bonds%               float32
# dtype: object

# %%
df.describe()
# Out:
#                                 date        quarter      house_id  \
# count                         180808  180808.000000  1.808080e+05
# mean   2012-10-02 16:23:41.777797376     170.519656  7.561557e+05
# min              1992-01-05 00:00:00      88.000000  1.193000e+03
# 25%              2005-07-31 00:00:00     142.000000  3.779025e+05
# 50%              2015-02-28 00:00:00     180.000000  7.567740e+05
# 75%              2020-09-22 00:00:00     202.000000  1.135842e+06
# max              2024-09-30 00:00:00     218.000000  1.507903e+06
# std                              NaN      36.271176  4.359012e+05
#
#           year_build  purchase_price  %_change_between_offer_and_purchase  \
# count  180808.000000    1.808080e+05                        180808.000000
# mean     1955.065368    1.918066e+06                            -2.066850
# min      1000.000000    2.500340e+05                           -49.000000
# 25%      1931.000000    8.000000e+05                            -3.000000
# 50%      1965.000000    1.400000e+06                             0.000000
# 75%      1980.000000    2.450000e+06                             0.000000
# max      2024.000000    4.229000e+07                            49.000000
# std        45.207596    1.762107e+06                             4.769722
#
#             no_rooms            sqm      sqm_price  nom_interest_rate%  \
# count  180808.000000  180808.000000  180808.000000       180808.000000
# mean        4.372871     129.222153   16354.367188            1.687039
# min         1.000000      26.000000     327.796234            0.000000
# 25%         3.000000      89.000000    6732.348633            0.000000
# 50%         4.000000     123.000000   12032.966797            0.750000
# 75%         5.000000     160.000000   21330.068848            3.250000
# max        15.000000     997.000000   75000.000000            9.500000
# std         1.647851      56.997082   13626.604492            2.048830
#
#        dk_ann_infl_rate%  yield_on_mortgage_credit_bonds%
# count      180808.000000                    180808.000000
# mean            1.932702                         4.123007
# min             0.250000                         1.100000
# 25%             0.790000                         2.120000
# 50%             1.850000                         4.340000
# 75%             2.340000                         5.500000
# max             7.700000                        10.140000
# std             1.638198                         2.198020

# %%
scaler = StandardScaler() # define the scaler
X_train_scaled = scaler.fit_transform(X_train) # apply to the training feature matrix
X_test_scaled = scaler.transform(X_test) # apply to the testing feature matrix

# %%
robust_scaler = RobustScaler() # define the scaler
X_train_robust = robust_scaler.fit_transform(X_train) # apply to the training feature matrix
X_test_robust = robust_scaler.transform(X_test) # apply to the testing feature matrix

# %%
knn = KNeighborsRegressor()
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
# print scores
print("Score on training set: {:.3f}".format(knn.score(X_train, y_train)))
print("Score on test set: {:.3f}".format(knn.score(X_test, y_test)))
# Out:
# Score on training set: 0.426
# Score on test set: 0.133

# %%
knn_scaled = KNeighborsRegressor()
knn_scaled.fit(X_train_scaled, y_train)
# Out:
# KNeighborsRegressor()

# %%
# print scores
print("Score on training set: {:.3f}".format(knn_scaled.score(X_train_scaled, y_train)))
print("Score on test set: {:.3f}".format(knn_scaled.score(X_test_scaled, y_test)))
# Out:
# Score on training set: 0.624
# Score on test set: 0.425

# %%
knn_robust = KNeighborsRegressor()
knn_robust.fit(X_train_robust, y_train)
# Out:
# KNeighborsRegressor()

# %%
# print scores
print("Score on training set: {:.3f}".format(knn_robust.score(X_train_robust, y_train)))
print("Score on test set: {:.3f}".format(knn_robust.score(X_test_robust, y_test)))
# Out:
# Score on training set: 0.613
# Score on test set: 0.407

# %%
plt.boxplot(df['sqm'])
plt.title('Boxplot of sqm')
plt.xticks([])  
plt.show()

# %%
param_grid = {
    'n_neighbors': [1, 5, 10, 20, 30, 40, 50, 60], # what should we set k to? 
    'weights': ['uniform', 'distance'], # uniform weighting vs. distance weighting
    'p': [1, 2], # 1 for manhattan vs. 2 for euclidean distance
}

# %%
grid_search = GridSearchCV(estimator=knn_robust,  # the model being tuned
                           param_grid=param_grid,  # dictionary of parameter values to search over
                           cv=5,  # number of folds to use
                           scoring='r2',  # evaluation metric
                           return_train_score=True,  # whether to return training scores in the output.
                           verbose=3)  # controls the verbosity of the output (i.e., how much output to print)

# fit the model with training data X_train_robust and target y_train
grid_search.fit(X_train_robust, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5] END n_neighbors=1, p=1, weights=uniform;, score=(train=0.999, test=0.145) total time=   5.5s
# [CV 2/5] END n_neighbors=1, p=1, weights=uniform;, score=(train=0.999, test=0.139) total time=   6.4s
# [CV 3/5] END n_neighbors=1, p=1, weights=uniform;, score=(train=0.999, test=0.131) total time=   6.3s
# [CV 4/5] END n_neighbors=1, p=1, weights=uniform;, score=(train=0.999, test=0.182) total time=   7.4s
# [CV 5/5] END n_neighbors=1, p=1, weights=uniform;, score=(train=0.999, test=0.129) total time=   6.7s
# [CV 1/5] END n_neighbors=1, p=1, weights=distance;, score=(train=0.999, test=0.145) total time=   7.1s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 9
#       1 grid_search = GridSearchCV(estimator=knn_robust,  # the model being tuned
#       2                            param_grid=param_grid,  # dictionary of parameter values to search over
#       3                            cv=5,  # number of folds to use
#       4                            scoring='r2',  # evaluation metric
#       5                            return_train_score=True,  # whether to return training scores in the output.
#       6                            verbose=3)  # controls the verbosity of the output (i.e., how much output to print)
#       8 # fit the model with training data X_train_robust and target y_train
# ----> 9 grid_search.fit(X_train_robust, y_train)
#
# File c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1051, in BaseSearchCV.fit(self, X, y, **params)
#    1045     results = self._format_results(
#    1046         all_candidate_params, n_splits, all_out, all_more_results
#    1047     )
#    1049     return results
# -> 1051 self._run_search(evaluate_candidates)
#    1053 # multimetric is determined here because in the case of a callable
#    1054 # self.scoring the return type is only known after calling
#    1055 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\sklearn\model_selection\_search.py:1605, in GridSearchCV._run_search(self, evaluate_candidates)
#    1603 def _run_search(self, evaluate_candidates):
#    1604     """Search all candidates in param_grid"""
# -> 1605     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\sklearn\model_selection\_search.py:997, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     989 if self.verbose > 0:
#     990     print(
#     991         "Fitting {0} folds for each of {1} candidates,"
#     992         " totalling {2} fits".format(
#     993             n_splits, n_candidates, n_candidates * n_splits
#     994         )
#     995     )
# --> 997 out = parallel(
#     998     delayed(_fit_and_score)(
#     999         clone(base_estimator),
#    1000         X,
#    1001         y,
#    1002         train=train,
#    1003         test=test,
#    1004         parameters=parameters,
#    1005         split_progress=(split_idx, n_splits),
#    1006         candidate_progress=(cand_idx, n_candidates),
#    1007         **fit_and_score_kwargs,
#    1008     )
#    1009     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#    1010         enumerate(candidate_params),
#    1011         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#    1012     )
#    1013 )
#    1015 if len(out) < 1:
#    1016     raise ValueError(
#    1017         "No fits were performed. "
#    1018         "Was the CV iterator empty? "
#    1019         "Were there no candidates?"
#    1020     )
#
# File c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\sklearn\utils\parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\sklearn\utils\parallel.py:147, in _FuncWrapper.__call__(self, *args, **kwargs)
#     145 with config_context(**config), warnings.catch_warnings():
#     146     warnings.filters = warning_filters
# --> 147     return self.function(*args, **kwargs)
#
# File c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\sklearn\model_selection\_validation.py:886, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     884     score_time = time.time() - start_time - fit_time
#     885     if return_train_score:
# --> 886         train_scores = _score(
#     887             estimator, X_train, y_train, scorer, score_params_train, error_score
#     888         )
#     890 if verbose > 1:
#     891     total_time = score_time + fit_time
#
# File c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\sklearn\model_selection\_validation.py:942, in _score(estimator, X_test, y_test, scorer, score_params, error_score)
#     940         scores = scorer(estimator, X_test, **score_params)
#     941     else:
# --> 942         scores = scorer(estimator, X_test, y_test, **score_params)
#     943 except Exception:
#     944     if isinstance(scorer, _MultimetricScorer):
#     945         # If `_MultimetricScorer` raises exception, the `error_score`
#     946         # parameter is equal to "raise".
#
# File c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\sklearn\metrics\_scorer.py:308, in _BaseScorer.__call__(self, estimator, X, y_true, sample_weight, **kwargs)
#     305 if sample_weight is not None:
#     306     _kwargs["sample_weight"] = sample_weight
# --> 308 return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#
# File c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\sklearn\metrics\_scorer.py:400, in _Scorer._score(self, method_caller, estimator, X, y_true, **kwargs)
#     398 pos_label = None if is_regressor(estimator) else self._get_pos_label()
#     399 response_method = _check_response_method(estimator, self._response_method)
# --> 400 y_pred = method_caller(
#     401     estimator,
#     402     _get_response_method_name(response_method),
#     403     X,
#     404     pos_label=pos_label,
#     405 )
#     407 scoring_kwargs = {**self._kwargs, **kwargs}
#     408 return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#
# File c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\sklearn\metrics\_scorer.py:90, in _cached_call(cache, estimator, response_method, *args, **kwargs)
#      87 if cache is not None and response_method in cache:
#      88     return cache[response_method]
# ---> 90 result, _ = _get_response_values(
#      91     estimator, *args, response_method=response_method, **kwargs
#      92 )
#      94 if cache is not None:
#      95     cache[response_method] = result
#
# File c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\sklearn\utils\_response.py:242, in _get_response_values(estimator, X, response_method, pos_label, return_response_method_used)
#     235         raise ValueError(
#     236             f"{estimator.__class__.__name__} should either be a classifier to be "
#     237             f"used with response_method={response_method} or the response_method "
#     238             "should be 'predict'. Got a regressor with response_method="
#     239             f"{response_method} instead."
#     240         )
#     241     prediction_method = estimator.predict
# --> 242     y_pred, pos_label = prediction_method(X), None
#     244 if return_response_method_used:
#     245     return y_pred, pos_label, prediction_method.__name__
#
# File c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\sklearn\neighbors\_regression.py:246, in KNeighborsRegressor.predict(self, X)
#     244     neigh_dist = None
#     245 else:
# --> 246     neigh_dist, neigh_ind = self.kneighbors(X)
#     248 weights = _get_weights(neigh_dist, self.weights)
#     250 _y = self._y
#
# File c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\sklearn\neighbors\_base.py:869, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     862 use_pairwise_distances_reductions = (
#     863     self._fit_method == "brute"
#     864     and ArgKmin.is_usable_for(
#     865         X if X is not None else self._fit_X, self._fit_X, self.effective_metric_
#     866     )
#     867 )
#     868 if use_pairwise_distances_reductions:
# --> 869     results = ArgKmin.compute(
#     870         X=X,
#     871         Y=self._fit_X,
#     872         k=n_neighbors,
#     873         metric=self.effective_metric_,
#     874         metric_kwargs=self.effective_metric_params_,
#     875         strategy="auto",
#     876         return_distance=return_distance,
#     877     )
#     879 elif (
#     880     self._fit_method == "brute" and self.metric == "precomputed" and issparse(X)
#     881 ):
#     882     results = _kneighbors_from_graph(
#     883         X, n_neighbors=n_neighbors, return_distance=return_distance
#     884     )
#
# File c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py:281, in ArgKmin.compute(cls, X, Y, k, metric, chunk_size, metric_kwargs, strategy, return_distance)
#     200 """Compute the argkmin reduction.
#     201
#     202 Parameters
#    (...)    278 returns.
#     279 """
#     280 if X.dtype == Y.dtype == np.float64:
# --> 281     return ArgKmin64.compute(
#     282         X=X,
#     283         Y=Y,
#     284         k=k,
#     285         metric=metric,
#     286         chunk_size=chunk_size,
#     287         metric_kwargs=metric_kwargs,
#     288         strategy=strategy,
#     289         return_distance=return_distance,
#     290     )
#     292 if X.dtype == Y.dtype == np.float32:
#     293     return ArgKmin32.compute(
#     294         X=X,
#     295         Y=Y,
#    (...)    301         return_distance=return_distance,
#     302     )
#
# File sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx:59, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute()
#
# File c:\Users\youne\OneDrive\Skrivebord\Test Python\.venv\Lib\site-packages\threadpoolctl.py:592, in _ThreadpoolLimiter.__exit__(self, type, value, traceback)
#     589 def __enter__(self):
#     590     return self
# --> 592 def __exit__(self, type, value, traceback):
#     593     self.restore_original_limits()
#     595 @classmethod
#     596 def wrap(cls, controller, *, limits=None, user_api=None):
#
# KeyboardInterrupt:

# %%
print("Best hyperparameter settings found: ", grid_search.best_params_)
# Out:
# Best hyperparameter settings found:  {'n_neighbors': 20, 'p': 1, 'weights': 'distance'}

# %%
best_knn = grid_search.best_estimator_
print("Score on training set: {:.3f}".format(best_knn.score(X_train_robust, y_train)))
print("Score on test set: {:.3f}".format(best_knn.score(X_test_robust, y_test)))
# Out:
# Score on training set: 1.000
# Score on test set: 0.494

# %%
from sklearn.pipeline import Pipeline

# define the pipeline with a placeholder scaler and the KNN regressor
pipe = Pipeline([
    ('scaler', StandardScaler()),  # Placeholder scaler
    ('knn', KNeighborsRegressor())
])

# define the parameter grid to include different scalers and KNN parameters
param_grid = {
    'scaler': [StandardScaler(),  RobustScaler(), 'passthrough'],  # different scaling methods (`passthrough` means no scaling)
    'knn__n_neighbors': [3, 6, 12, 24, 48, 96],
    'knn__weights': ['uniform', 'distance'],
    'knn__p': [1, 2],
}

# set up GridSearchCV with the pipeline and parameter grid
grid_search = GridSearchCV(
    estimator=pipe,
    param_grid=param_grid,
    cv=3,
    scoring='r2',
    return_train_score=True,
    verbose=3
)

#fit the model with the original training data (without prior scaling)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 72 candidates, totalling 216 fits
# [CV 1/3] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.696, test=0.373) total time=   0.2s
# [CV 2/3] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.688, test=0.380) total time=   0.2s
# [CV 3/3] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.688, test=0.394) total time=   0.2s
# [CV 1/3] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.694, test=0.357) total time=   0.2s
# [CV 2/3] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.686, test=0.378) total time=   0.2s
# [CV 3/3] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.687, test=0.380) total time=   0.2s
# [CV 1/3] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.534, test=0.067) total time=   0.2s
# [CV 2/3] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.534, test=0.096) total time=   0.2s
# [CV 3/3] END knn__n_neighbors=3, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.534, test=0.083) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.368) total time=   0.2s
# [CV 2/3] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.373) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.386) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.353) total time=   0.3s
# [CV 2/3] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.372) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.375) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.072) total time=   0.2s
# [CV 2/3] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.098) total time=   0.2s
# [CV 3/3] END knn__n_neighbors=3, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.086) total time=   0.2s
# [CV 1/3] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.691, test=0.377) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.690, test=0.359) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.686, test=0.381) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.690, test=0.353) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.681, test=0.363) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.676, test=0.368) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.494, test=-0.025) total time=   0.0s
# [CV 2/3] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.485, test=-0.013) total time=   0.0s
# [CV 3/3] END knn__n_neighbors=3, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.495, test=-0.009) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.372) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.354) total time=   0.0s
# [CV 3/3] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.377) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.352) total time=   0.2s
# [CV 2/3] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.360) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.363) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=-0.023) total time=   0.0s
# [CV 2/3] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=-0.011) total time=   0.0s
# [CV 3/3] END knn__n_neighbors=3, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=-0.010) total time=   0.0s
# [CV 1/3] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.601, test=0.432) total time=   0.2s
# [CV 2/3] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.595, test=0.436) total time=   0.2s
# [CV 3/3] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.594, test=0.452) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.598, test=0.433) total time=   0.3s
# [CV 2/3] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.596, test=0.437) total time=   0.2s
# [CV 3/3] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.591, test=0.443) total time=   0.2s
# [CV 1/3] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.406, test=0.165) total time=   0.2s
# [CV 2/3] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.406, test=0.182) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=6, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.406, test=0.171) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.434) total time=   0.4s
# [CV 2/3] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.437) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.448) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.435) total time=   0.3s
# [CV 2/3] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.437) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.442) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.168) total time=   0.2s
# [CV 2/3] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.189) total time=   0.2s
# [CV 3/3] END knn__n_neighbors=6, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.177) total time=   0.2s
# [CV 1/3] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.595, test=0.429) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.592, test=0.428) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.590, test=0.448) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.589, test=0.421) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.594, test=0.422) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.583, test=0.439) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.365, test=0.091) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.358, test=0.116) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=6, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.354, test=0.103) total time=   0.0s
# [CV 1/3] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.433) total time=   0.2s
# [CV 2/3] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.428) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.448) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.426) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.423) total time=   0.2s
# [CV 3/3] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.439) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.091) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.115) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=6, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.100) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.542, test=0.444) total time=   0.4s
# [CV 2/3] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.537, test=0.458) total time=   0.4s
# [CV 3/3] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.531, test=0.469) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.546, test=0.449) total time=   0.4s
# [CV 2/3] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.535, test=0.461) total time=   0.4s
# [CV 3/3] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.539, test=0.472) total time=   0.4s
# [CV 1/3] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.349, test=0.205) total time=   0.4s
# [CV 2/3] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.337, test=0.224) total time=   0.4s
# [CV 3/3] END knn__n_neighbors=12, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.337, test=0.217) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.453) total time=   0.3s
# [CV 2/3] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.464) total time=   0.4s
# [CV 3/3] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.474) total time=   0.4s
# [CV 1/3] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.456) total time=   0.4s
# [CV 2/3] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.468) total time=   0.4s
# [CV 3/3] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.475) total time=   0.4s
# [CV 1/3] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.211) total time=   0.3s
# [CV 2/3] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.235) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=12, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.223) total time=   0.4s
# [CV 1/3] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.541, test=0.449) total time=   0.2s
# [CV 2/3] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.534, test=0.452) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.530, test=0.472) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.539, test=0.444) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.532, test=0.452) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.526, test=0.453) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.304, test=0.156) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.295, test=0.166) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=12, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.288, test=0.165) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.458) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.459) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.477) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.452) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.459) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.461) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.156) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.170) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=12, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.164) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=24, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.501, test=0.436) total time=   0.3s
# [CV 2/3] END knn__n_neighbors=24, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.493, test=0.451) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=24, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.484, test=0.467) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=24, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.510, test=0.444) total time=   0.3s
# [CV 2/3] END knn__n_neighbors=24, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.499, test=0.462) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=24, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.495, test=0.469) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=24, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.305, test=0.233) total time=   0.3s
# [CV 2/3] END knn__n_neighbors=24, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.295, test=0.239) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=24, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.293, test=0.235) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=24, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.452) total time=   0.3s
# [CV 2/3] END knn__n_neighbors=24, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.465) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=24, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.478) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=24, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.458) total time=   0.3s
# [CV 2/3] END knn__n_neighbors=24, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.474) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=24, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.479) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=24, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.238) total time=   0.3s
# [CV 2/3] END knn__n_neighbors=24, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.250) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=24, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.242) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=24, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.500, test=0.437) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=24, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.491, test=0.446) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=24, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.484, test=0.462) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=24, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.501, test=0.431) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=24, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.491, test=0.453) total time=   0.2s
# [CV 3/3] END knn__n_neighbors=24, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.485, test=0.455) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=24, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.260, test=0.189) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=24, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.260, test=0.194) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=24, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.256, test=0.195) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=24, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.454) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=24, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.460) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=24, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.474) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=24, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.446) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=24, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.465) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=24, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.467) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=24, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.189) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=24, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.198) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=24, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.195) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.464, test=0.418) total time=   0.4s
# [CV 2/3] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.456, test=0.434) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.445, test=0.444) total time=   0.4s
# [CV 1/3] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.479, test=0.429) total time=   0.4s
# [CV 2/3] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.466, test=0.451) total time=   0.4s
# [CV 3/3] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.458, test=0.453) total time=   0.4s
# [CV 1/3] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.270, test=0.236) total time=   0.3s
# [CV 2/3] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.268, test=0.241) total time=   0.4s
# [CV 3/3] END knn__n_neighbors=48, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.268, test=0.242) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.440) total time=   0.4s
# [CV 2/3] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.454) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.463) total time=   0.4s
# [CV 1/3] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.447) total time=   0.3s
# [CV 2/3] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.468) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.469) total time=   0.4s
# [CV 1/3] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.244) total time=   0.3s
# [CV 2/3] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.253) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=48, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.249) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.462, test=0.419) total time=   0.2s
# [CV 2/3] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.456, test=0.430) total time=   0.2s
# [CV 3/3] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.442, test=0.446) total time=   0.2s
# [CV 1/3] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.469, test=0.419) total time=   0.2s
# [CV 2/3] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.455, test=0.443) total time=   0.2s
# [CV 3/3] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.449, test=0.441) total time=   0.2s
# [CV 1/3] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.236, test=0.205) total time=   0.1s
# [CV 2/3] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.237, test=0.204) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=48, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.233, test=0.206) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.440) total time=   0.2s
# [CV 2/3] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.449) total time=   0.2s
# [CV 3/3] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.465) total time=   0.2s
# [CV 1/3] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.437) total time=   0.2s
# [CV 2/3] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.459) total time=   0.2s
# [CV 3/3] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.457) total time=   0.2s
# [CV 1/3] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.207) total time=   0.2s
# [CV 2/3] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.209) total time=   0.1s
# [CV 3/3] END knn__n_neighbors=48, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.208) total time=   0.1s
# [CV 1/3] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.426, test=0.392) total time=   0.4s
# [CV 2/3] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.419, test=0.407) total time=   0.5s
# [CV 3/3] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.405, test=0.416) total time=   0.5s
# [CV 1/3] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.445, test=0.409) total time=   0.4s
# [CV 2/3] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.434, test=0.427) total time=   0.4s
# [CV 3/3] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.423, test=0.430) total time=   0.5s
# [CV 1/3] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.248, test=0.232) total time=   0.5s
# [CV 2/3] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.247, test=0.233) total time=   0.5s
# [CV 3/3] END knn__n_neighbors=96, knn__p=1, knn__weights=uniform, scaler=passthrough;, score=(train=0.244, test=0.231) total time=   0.4s
# [CV 1/3] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.419) total time=   0.5s
# [CV 2/3] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.433) total time=   0.4s
# [CV 3/3] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.442) total time=   0.5s
# [CV 1/3] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.430) total time=   0.5s
# [CV 2/3] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.448) total time=   0.5s
# [CV 3/3] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.450) total time=   0.5s
# [CV 1/3] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.242) total time=   0.4s
# [CV 2/3] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.245) total time=   0.5s
# [CV 3/3] END knn__n_neighbors=96, knn__p=1, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.242) total time=   0.4s
# [CV 1/3] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.421, test=0.388) total time=   0.3s
# [CV 2/3] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.415, test=0.399) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=StandardScaler();, score=(train=0.401, test=0.411) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.432, test=0.398) total time=   0.3s
# [CV 2/3] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.420, test=0.415) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=RobustScaler();, score=(train=0.413, test=0.413) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.221, test=0.209) total time=   0.2s
# [CV 2/3] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.224, test=0.205) total time=   0.2s
# [CV 3/3] END knn__n_neighbors=96, knn__p=2, knn__weights=uniform, scaler=passthrough;, score=(train=0.217, test=0.210) total time=   0.2s
# [CV 1/3] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.415) total time=   0.3s
# [CV 2/3] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.424) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=StandardScaler();, score=(train=1.000, test=0.435) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.418) total time=   0.3s
# [CV 2/3] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.435) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=RobustScaler();, score=(train=1.000, test=0.433) total time=   0.3s
# [CV 1/3] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.212) total time=   0.2s
# [CV 2/3] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.211) total time=   0.3s
# [CV 3/3] END knn__n_neighbors=96, knn__p=2, knn__weights=distance, scaler=passthrough;, score=(train=1.000, test=0.214) total time=   0.3s
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('knn', KNeighborsRegressor())]),
#              param_grid={'knn__n_neighbors': [3, 6, 12, 24, 48, 96],
#                          'knn__p': [1, 2],
#                          'knn__weights': ['uniform', 'distance'],
#                          'scaler': [StandardScaler(), RobustScaler(),
#                                     'passthrough']},
#              return_train_score=True, scoring='r2', verbose=3)

# %%
print("Best hyperparameter settings found: ", grid_search.best_params_)
# Out:
# Best hyperparameter settings found:  {'knn__n_neighbors': 24, 'knn__p': 1, 'knn__weights': 'distance', 'scaler': RobustScaler()}
