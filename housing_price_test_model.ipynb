# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %% [markdown]
# Storing the data in a dataframe

# %%
df = pd.read_parquet("DKHousingPrices.parquet")

# %%
print(df["date"].min(), "to", df["date"].max())
df.head()
# Out:
# 1992-01-05 00:00:00 to 2024-10-26 00:00:00
#         date quarter  house_id   house_type    sales_type  year_build  \
# 0 2024-10-26  2024Q4         0        Villa  regular_sale        1974
# 1 2024-10-26  2024Q4         2  Summerhouse  regular_sale        1956
# 2 2024-10-26  2024Q4         1         Farm  regular_sale        1955
# 3 2024-10-25  2024Q4         3    Apartment   family_sale        1945
# 4 2024-10-25  2024Q4         4        Villa  regular_sale        1967
#
#    purchase_price  %_change_between_offer_and_purchase  no_rooms    sqm  \
# 0         4350000                                  0.0         5  215.0
# 1          450000                                  0.0         3   36.0
# 2         6600000                                  0.0         3  180.0
# 3         1495000                                  0.0         2   64.0
# 4         3375000                                  0.0         5  176.0
#
#       sqm_price                     address  zip_code        city  \
# 0  20232.558594               Kildevangen 5      8382    Hinnerup
# 1  12500.000000                Lykkestien 2      4400  Kalundborg
# 2  36666.667969               Sæderupvej 58      9260     Gistrup
# 3  23359.375000  Tage-Hansens Gade 5, 1. tv      8000    Aarhus C
# 4  19176.136719          Chr.Winthers Vej 5      8600   Silkeborg
#
#                  area   region  nom_interest_rate%  dk_ann_infl_rate%  \
# 0  East & mid jutland  Jutland                 3.1                NaN
# 1       Other islands  Zealand                 3.1                NaN
# 2       North jutland  Jutland                 3.1                NaN
# 3  East & mid jutland  Jutland                 3.1                NaN
# 4  East & mid jutland  Jutland                 3.1                NaN
#
#    yield_on_mortgage_credit_bonds%
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN

# %%
#Drop all rows with na in the sqm column
df = df.dropna(subset=["city", "quarter","house_type", "sales_type", "year_build", "no_rooms", "sqm", "area", "dk_ann_infl_rate%", "nom_interest_rate%", "yield_on_mortgage_credit_bonds%"])
df.head()
# Out:
#            date quarter  house_id   house_type    sales_type  year_build  \
# 1193 2024-09-30  2024Q3      1300    Apartment  regular_sale        1971
# 1194 2024-09-30  2024Q3      1307  Summerhouse  regular_sale        2009
# 1195 2024-09-30  2024Q3      1301    Apartment  regular_sale        1940
# 1196 2024-09-30  2024Q3      1302  Summerhouse   family_sale        1950
# 1197 2024-09-30  2024Q3      1303    Apartment  regular_sale        1974
#
#       purchase_price  %_change_between_offer_and_purchase  no_rooms   sqm  \
# 1193         1765000                                  0.0         3  78.0
# 1194          590939                                  0.0         3  50.0
# 1195         1750000                                  0.0         2  56.0
# 1196         1080000                                  0.0         4  72.0
# 1197         2300000                                  0.0         1  50.0
#
#          sqm_price                  address  zip_code            city  \
# 1193  22628.205078      Hedekæret 38, 1. th      2640      Hedehusene
# 1194  11818.780273             Violstien 11      2635           Ishøj
# 1195  31250.000000  Buddingevej 72I, st. tv      2800  Kongens Lyngby
# 1196  15000.000000          Frederiksvej 35      3730            Nexø
# 1197  46000.000000     Thyrasgade 4, 4. 508      2200     København N
#
#                      area    region  nom_interest_rate%  dk_ann_infl_rate%  \
# 1193  Capital, Copenhagen   Zealand                3.35               1.13
# 1194  Capital, Copenhagen   Zealand                3.35               1.13
# 1195  Capital, Copenhagen   Zealand                3.35               1.13
# 1196             Bornholm  Bornholm                3.35               1.13
# 1197  Capital, Copenhagen   Zealand                3.35               1.13
#
#       yield_on_mortgage_credit_bonds%
# 1193                             4.34
# 1194                             4.34
# 1195                             4.34
# 1196                             4.34
# 1197                             4.34

# %% [markdown]
# Quarter skal laves til en float istedet for datetime

# %% [markdown]
# ### Make dummy variables

# %%
X = pd.get_dummies(df[["quarter","house_type", "sales_type", "year_build", "no_rooms", "sqm", "area", "nom_interest_rate%" ]])
y = df["purchase_price"]
X.shape, y.shape
X.head()
# Out:
#      quarter  year_build  no_rooms   sqm  nom_interest_rate%  \
# 1193  2024Q3        1971         3  78.0                3.35
# 1194  2024Q3        2009         3  50.0                3.35
# 1195  2024Q3        1940         2  56.0                3.35
# 1196  2024Q3        1950         4  72.0                3.35
# 1197  2024Q3        1974         1  50.0                3.35
#
#       house_type_Apartment  house_type_Farm  house_type_Summerhouse  \
# 1193                  True            False                   False
# 1194                 False            False                    True
# 1195                  True            False                   False
# 1196                 False            False                    True
# 1197                  True            False                   False
#
#       house_type_Townhouse  house_type_Villa  ...  sales_type_other_sale  \
# 1193                 False             False  ...                  False
# 1194                 False             False  ...                  False
# 1195                 False             False  ...                  False
# 1196                 False             False  ...                  False
# 1197                 False             False  ...                  False
#
#       sales_type_regular_sale  area_Bornholm  area_Capital, Copenhagen  \
# 1193                     True          False                      True
# 1194                     True          False                      True
# 1195                     True          False                      True
# 1196                    False           True                     False
# 1197                     True          False                      True
#
#       area_East & mid jutland  area_Fyn & islands  area_North Zealand  \
# 1193                    False               False               False
# 1194                    False               False               False
# 1195                    False               False               False
# 1196                    False               False               False
# 1197                    False               False               False
#
#       area_North jutland  area_Other islands  area_South jutland
# 1193               False               False               False
# 1194               False               False               False
# 1195               False               False               False
# 1196               False               False               False
# 1197               False               False               False
#
# [5 rows x 23 columns]

# %% [markdown]
# Make the training and testing split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create and fit the model
simple_model = LinearRegression()
simple_model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 # Create and fit the model
#       2 simple_model = LinearRegression()
# ----> 3 simple_model.fit(X_train, y_train)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\linear_model\_base.py:678, in LinearRegression.fit(self, X, y, sample_weight)
#     674 n_jobs_ = self.n_jobs
#     676 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 678 X, y = self._validate_data(
#     679     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     680 )
#     682 has_sw = sample_weight is not None
#     683 if has_sw:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\base.py:622, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     620         y = check_array(y, input_name="y", **check_y_params)
#     621     else:
# --> 622         X, y = check_X_y(X, y, **check_params)
#     623     out = X, y
#     625 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py:1146, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1141         estimator_name = _check_estimator_name(estimator)
#    1142     raise ValueError(
#    1143         f"{estimator_name} requires y to be passed, but the target y is None"
#    1144     )
# -> 1146 X = check_array(
#    1147     X,
#    1148     accept_sparse=accept_sparse,
#    1149     accept_large_sparse=accept_large_sparse,
#    1150     dtype=dtype,
#    1151     order=order,
#    1152     copy=copy,
#    1153     force_all_finite=force_all_finite,
#    1154     ensure_2d=ensure_2d,
#    1155     allow_nd=allow_nd,
#    1156     ensure_min_samples=ensure_min_samples,
#    1157     ensure_min_features=ensure_min_features,
#    1158     estimator=estimator,
#    1159     input_name="X",
#    1160 )
#    1162 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1164 check_consistent_length(X, y)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py:836, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     831 if pandas_requires_conversion:
#     832     # pandas dataframe requires conversion earlier to handle extension dtypes with
#     833     # nans
#     834     # Use the original dtype for conversion if dtype is None
#     835     new_dtype = dtype_orig if dtype is None else dtype
# --> 836     array = array.astype(new_dtype)
#     837     # Since we converted here, we do not need to convert again later
#     838     dtype = None
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# --> 451 return self.apply(
#     452     "astype",
#     453     dtype=dtype,
#     454     copy=copy,
#     455     errors=errors,
#     456     using_cow=using_copy_on_write(),
#     457 )
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\blocks.py:511, in Block.astype(self, dtype, copy, errors, using_cow)
#     491 """
#     492 Coerce to the new dtype.
#     493
#    (...)
#     507 Block
#     508 """
#     509 values = self.values
# --> 511 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     513 new_values = maybe_coerce_values(new_values)
#     515 refs = None
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\dtypes\astype.py:242, in astype_array_safe(values, dtype, copy, errors)
#     239     dtype = dtype.numpy_dtype
#     241 try:
# --> 242     new_values = astype_array(values, dtype, copy=copy)
#     243 except (ValueError, TypeError):
#     244     # e.g. _astype_nansafe can fail on object-dtype of strings
#     245     #  trying to convert to float
#     246     if errors == "ignore":
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\dtypes\astype.py:184, in astype_array(values, dtype, copy)
#     180     return values
#     182 if not isinstance(values, np.ndarray):
#     183     # i.e. ExtensionArray
# --> 184     values = values.astype(dtype, copy=copy)
#     186 else:
#     187     values = _astype_nansafe(values, dtype, copy=copy)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\arrays\period.py:664, in PeriodArray.astype(self, dtype, copy)
#     661     tz = getattr(dtype, "tz", None)
#     662     return self.to_timestamp().tz_localize(tz)
# --> 664 return super().astype(dtype, copy=copy)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\arrays\datetimelike.py:487, in DatetimeLikeArrayMixin.astype(self, dtype, copy)
#     480 elif (
#     481     is_datetime_or_timedelta_dtype(dtype)
#     482     and not is_dtype_equal(self.dtype, dtype)
#     483 ) or is_float_dtype(dtype):
#     484     # disallow conversion between datetime/timedelta,
#     485     # and conversions for any datetimelike to float
#     486     msg = f"Cannot cast {type(self).__name__} to dtype {dtype}"
# --> 487     raise TypeError(msg)
#     488 else:
#     489     return np.asarray(self, dtype=dtype)
#
# TypeError: Cannot cast PeriodArray to dtype float64

# %%
#Evaluate the model
print("Score on training set: {:.3f}".format(simple_model.score(X_train, y_train)))
print("Score on test set: {:.3f}".format(simple_model.score(X_test, y_test)))
# Out:
# Score on training set: 0.338
# Score on test set: 0.333
